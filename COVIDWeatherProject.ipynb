# %% [markdown]
# # Does climate impact the number of COVID cases?
#
#
# This analysis takes a look at climate factors, including temperature and humidity, for ten cities around the United States.  Additionally, we look at the impact the climate factors have on time outside of the home in comparison to the amount of COVID cases. Does a warmer climate cause a higher new case rate of COVID in these cities? Does higher humidity mean higher percentage of cases? We also analyze the latitude of each city to see if that relates to climate and COVID-cases as well by utilizing Google API.
#
#
# The cities we are using to analyze include: Boston, Dallas, Denver, Detroit, Honolulu, Los Angeles, Miami, New York City, San Francisco, and Seattle. We selected cities that have no overall bias to location within the United States to get as accurate description of different climates, while also picking similar metropolitan areas.

# %% [markdown]
# # Back End Analysis

# %%
#Import Dependencies 
import pandas as pd
import numpy as np
import csv
import matplotlib.pyplot as plt
import requests
from scipy.stats import linregress
from sklearn import datasets
import gmaps
import json
import random
from pprint import pprint
from citipy import citipy
import seaborn as sns
import scipy.stats as st
import scipy.stats as stats

#import api_key
#from config import api_key

#import api_key - Jess
api_key="e9f34fe30c3508b1804ca865ed96b3b4"


# Configure gmaps
gmaps.configure(api_key=api_key)


#create city list
city_list=[
"Boston",
"Miami",
"Seattle",
"New York City",
"Dallas",
"Denver",
"Los Angeles", 
"San Francisco",
"Detroit",
"Honolulu",
]

# %%
#Reference & Read CSV files
csv_path_all="Resources/TempResources/marchseptember.csv"
csv_path_covid="Resources/CSVFiles/completed_covid_cases_data.csv"

city_data=pd.read_csv("Resources/DataFiles/GeoIDs - City.csv")
covid_daily_cases=pd.read_csv("Resources/DataFiles/COVID Cases - City - Daily.csv")
daily_mobility=pd.read_csv("Resources/DataFiles/Google Mobility - City - Daily.csv")

covid_df=pd.read_csv(csv_path_covid, encoding="utf-8")
city_df=pd.read_csv(csv_path_all, encoding="utf-8")

# %% [markdown]
# # COVID Cases & GPS Data

# %% [markdown]
# The following data was pulled from the Tracktherecovery.com and organized/cleaned by Will.

# %%
#Covid Case Information & GPS Information
city_data=city_data.loc[city_data['cityname'].isin(city_list)]
city_data
# Out:
#     cityid       cityname stateabbrev      statename  statefips  city_pop2019
# 0        1    Los Angeles          CA     California          6      10039107
# 1        2  New York City          NY       New York         36       8336817
# 6        7         Dallas          TX          Texas         48       2635516
# 8        9        Seattle          WA     Washington         53       2252782
# 12      13        Detroit          MI       Michigan         26       1749343
# 20      21  San Francisco          CA     California          6        881549
# 24      25         Boston          MA  Massachusetts         25        803907
# 27      28         Denver          CO       Colorado          8        727211
# 37      38          Miami          FL        Florida         12       2716940
# 47      48       Honolulu          HI         Hawaii         15        974563

# %% [markdown]
# # Merging City Case Data

# %%
#merge city data and covid daily cases
merge1=pd.merge(city_data,covid_daily_cases,on="cityid",how="left")
merge1.head()
# Out:
#    cityid     cityname stateabbrev   statename  statefips  city_pop2019  year  \
# 0       1  Los Angeles          CA  California          6      10039107  2020
# 1       1  Los Angeles          CA  California          6      10039107  2020
# 2       1  Los Angeles          CA  California          6      10039107  2020
# 3       1  Los Angeles          CA  California          6      10039107  2020
# 4       1  Los Angeles          CA  California          6      10039107  2020
#
#    month  day  case_count  new_case_count  case_rate new_case_rate
# 0      1   21           0               0        0.0             .
# 1      1   22           0               0        0.0             .
# 2      1   23           0               0        0.0             .
# 3      1   24           0               0        0.0             .
# 4      1   25           0               0        0.0             .

# %%
data_df=pd.merge(merge1,daily_mobility,on=["cityid","month","day","year"],how="inner")
data_df
# Out:
#       cityid     cityname stateabbrev   statename  statefips  city_pop2019  \
# 0          1  Los Angeles          CA  California          6      10039107
# 1          1  Los Angeles          CA  California          6      10039107
# 2          1  Los Angeles          CA  California          6      10039107
# 3          1  Los Angeles          CA  California          6      10039107
# 4          1  Los Angeles          CA  California          6      10039107
# ...      ...          ...         ...         ...        ...           ...
# 2005      48     Honolulu          HI      Hawaii         15        974563
# 2006      48     Honolulu          HI      Hawaii         15        974563
# 2007      48     Honolulu          HI      Hawaii         15        974563
# 2008      48     Honolulu          HI      Hawaii         15        974563
# 2009      48     Honolulu          HI      Hawaii         15        974563
#
#       year  month  day  case_count  new_case_count  case_rate new_case_rate  \
# 0     2020      2   24           1               0    0.00996             0
# 1     2020      2   25           1               0    0.00996             0
# 2     2020      2   26           1               0    0.00996             0
# 3     2020      2   27           1               0    0.00996             0
# 4     2020      2   28           1               0    0.00996             0
# ...    ...    ...  ...         ...             ...        ...           ...
# 2005  2020      9    7        9000              89  923.00000          19.2
# 2006  2020      9    8        9114             114  935.00000          18.6
# 2007  2020      9    9        9202              88  944.00000          15.4
# 2008  2020      9   10        9360             158  960.00000            15
# 2009  2020      9   11        9503             143  975.00000          13.6
#
#       gps_retail_and_recreation  gps_grocery_and_pharmacy gps_parks  \
# 0                       0.00571                  -0.00286     .0714
# 1                       0.01000                  -0.00143     .0743
# 2                       0.01570                   0.00286     .0714
# 3                       0.01860                   0.00571     .0757
# 4                       0.02290                   0.01140       .08
# ...                         ...                       ...       ...
# 2005                   -0.41700                  -0.15400      -.51
# 2006                   -0.41700                  -0.15600     -.521
# 2007                   -0.41700                  -0.15300     -.516
# 2008                   -0.42000                  -0.15600     -.503
# 2009                   -0.42100                  -0.15700     -.489
#
#       gps_transit_stations  gps_workplaces  gps_residential  \
# 0                  0.00286          0.0214         -0.00143
# 1                  0.00429          0.0229         -0.00286
# 2                  0.00571          0.0243         -0.00429
# 3                  0.00714          0.0243         -0.00429
# 4                  0.01000          0.0257         -0.00571
# ...                    ...             ...              ...
# 2005              -0.62300         -0.4730          0.18900
# 2006              -0.61000         -0.4260          0.17300
# 2007              -0.61100         -0.4260          0.17300
# 2008              -0.61000         -0.4260          0.17300
# 2009              -0.61000         -0.4200          0.17100
#
#       gps_away_from_home
# 0               0.000625
# 1               0.002020
# 2               0.003620
# 3               0.003620
# 4               0.005000
# ...                  ...
# 2005           -0.231000
# 2006           -0.212000
# 2007           -0.212000
# 2008           -0.212000
# 2009           -0.211000
#
# [2010 rows x 20 columns]

# %%
#concatenate
data_df["concat"] = data_df["month"].astype(str) + data_df["day"].astype(str)

# %%
data_df
# Out:
#       cityid     cityname stateabbrev   statename  statefips  city_pop2019  \
# 0          1  Los Angeles          CA  California          6      10039107
# 1          1  Los Angeles          CA  California          6      10039107
# 2          1  Los Angeles          CA  California          6      10039107
# 3          1  Los Angeles          CA  California          6      10039107
# 4          1  Los Angeles          CA  California          6      10039107
# ...      ...          ...         ...         ...        ...           ...
# 2005      48     Honolulu          HI      Hawaii         15        974563
# 2006      48     Honolulu          HI      Hawaii         15        974563
# 2007      48     Honolulu          HI      Hawaii         15        974563
# 2008      48     Honolulu          HI      Hawaii         15        974563
# 2009      48     Honolulu          HI      Hawaii         15        974563
#
#       year  month  day  case_count  ...  case_rate  new_case_rate  \
# 0     2020      2   24           1  ...    0.00996              0
# 1     2020      2   25           1  ...    0.00996              0
# 2     2020      2   26           1  ...    0.00996              0
# 3     2020      2   27           1  ...    0.00996              0
# 4     2020      2   28           1  ...    0.00996              0
# ...    ...    ...  ...         ...  ...        ...            ...
# 2005  2020      9    7        9000  ...  923.00000           19.2
# 2006  2020      9    8        9114  ...  935.00000           18.6
# 2007  2020      9    9        9202  ...  944.00000           15.4
# 2008  2020      9   10        9360  ...  960.00000             15
# 2009  2020      9   11        9503  ...  975.00000           13.6
#
#      gps_retail_and_recreation  gps_grocery_and_pharmacy  gps_parks  \
# 0                      0.00571                  -0.00286      .0714
# 1                      0.01000                  -0.00143      .0743
# 2                      0.01570                   0.00286      .0714
# 3                      0.01860                   0.00571      .0757
# 4                      0.02290                   0.01140        .08
# ...                        ...                       ...        ...
# 2005                  -0.41700                  -0.15400       -.51
# 2006                  -0.41700                  -0.15600      -.521
# 2007                  -0.41700                  -0.15300      -.516
# 2008                  -0.42000                  -0.15600      -.503
# 2009                  -0.42100                  -0.15700      -.489
#
#      gps_transit_stations  gps_workplaces  gps_residential  \
# 0                 0.00286          0.0214         -0.00143
# 1                 0.00429          0.0229         -0.00286
# 2                 0.00571          0.0243         -0.00429
# 3                 0.00714          0.0243         -0.00429
# 4                 0.01000          0.0257         -0.00571
# ...                   ...             ...              ...
# 2005             -0.62300         -0.4730          0.18900
# 2006             -0.61000         -0.4260          0.17300
# 2007             -0.61100         -0.4260          0.17300
# 2008             -0.61000         -0.4260          0.17300
# 2009             -0.61000         -0.4200          0.17100
#
#       gps_away_from_home  concat
# 0               0.000625     224
# 1               0.002020     225
# 2               0.003620     226
# 3               0.003620     227
# 4               0.005000     228
# ...                  ...     ...
# 2005           -0.231000      97
# 2006           -0.212000      98
# 2007           -0.212000      99
# 2008           -0.212000     910
# 2009           -0.211000     911
#
# [2010 rows x 21 columns]

# %%
data_df["concat"] = data_df["concat"].astype(int)

completed_city_data=data_df.loc[(data_df['month'] >= 3)]

completed_city_data=completed_city_data.sort_values(by=['month', 'day'],ascending=False)

completed_city_data=completed_city_data[:-140]

# %%
completed_city_data.head()
# Out:
#       cityid       cityname stateabbrev   statename  statefips  city_pop2019  \
# 200        1    Los Angeles          CA  California          6      10039107
# 401        2  New York City          NY    New York         36       8336817
# 602        7         Dallas          TX       Texas         48       2635516
# 803        9        Seattle          WA  Washington         53       2252782
# 1004      13        Detroit          MI    Michigan         26       1749343
#
#       year  month  day  case_count  ...  case_rate  new_case_rate  \
# 200   2020      9   11      252066  ...     2511.0           8.05
# 401   2020      9   11      241936  ...     2902.0           3.08
# 602   2020      9   11       78291  ...     2971.0             12
# 803   2020      9   11       20718  ...      920.0           3.97
# 1004  2020      9   11       33138  ...     1894.0           10.5
#
#      gps_retail_and_recreation  gps_grocery_and_pharmacy  gps_parks  \
# 200                    -0.2910                   -0.1170     -.0557
# 401                    -0.2200                   -0.0590       .812
# 602                    -0.1570                   -0.0886       .234
# 803                    -0.2500                   -0.1060       .711
# 1004                   -0.0771                   -0.0614          .
#
#      gps_transit_stations  gps_workplaces  gps_residential  \
# 200                -0.431          -0.373           0.1200
# 401                -0.379          -0.413           0.1020
# 602                -0.336          -0.356           0.0843
# 803                -0.503          -0.469           0.1360
# 1004               -0.350          -0.346           0.0614
#
#       gps_away_from_home  concat
# 200              -0.1420     911
# 401              -0.1110     911
# 602              -0.0959     911
# 803              -0.1490     911
# 1004             -0.0638     911
#
# [5 rows x 21 columns]

# %%
completed_city_data['New Cases Per Million People']=round((completed_city_data['new_case_count']/(completed_city_data['city_pop2019']/1000000)),0)
completed_city_data['Total Cases Per Million People']=round((completed_city_data['case_count']/(completed_city_data['city_pop2019']/1000000)),0)

completed_city_data
# Out:
#       cityid       cityname stateabbrev      statename  statefips  \
# 200        1    Los Angeles          CA     California          6
# 401        2  New York City          NY       New York         36
# 602        7         Dallas          TX          Texas         48
# 803        9        Seattle          WA     Washington         53
# 1004      13        Detroit          MI       Michigan         26
# ...      ...            ...         ...            ...        ...
# 1025      21  San Francisco          CA     California          6
# 1226      25         Boston          MA  Massachusetts         25
# 1427      28         Denver          CO       Colorado          8
# 1628      38          Miami          FL        Florida         12
# 1829      48       Honolulu          HI         Hawaii         15
#
#       city_pop2019  year  month  day  case_count  ...  \
# 200       10039107  2020      9   11      252066  ...
# 401        8336817  2020      9   11      241936  ...
# 602        2635516  2020      9   11       78291  ...
# 803        2252782  2020      9   11       20718  ...
# 1004       1749343  2020      9   11       33138  ...
# ...            ...   ...    ...  ...         ...  ...
# 1025        881549  2020      3   15          37  ...
# 1226        803907  2020      3   15          31  ...
# 1427        727211  2020      3   15          28  ...
# 1628       2716940  2020      3   15          13  ...
# 1829        974563  2020      3   15           4  ...
#
#       gps_retail_and_recreation  gps_grocery_and_pharmacy gps_parks  \
# 200                     -0.2910                   -0.1170    -.0557
# 401                     -0.2200                   -0.0590      .812
# 602                     -0.1570                   -0.0886      .234
# 803                     -0.2500                   -0.1060      .711
# 1004                    -0.0771                   -0.0614         .
# ...                         ...                       ...       ...
# 1025                    -0.2190                    0.0829     -.136
# 1226                    -0.0957                    0.1460      .196
# 1427                    -0.0643                    0.2410      .314
# 1628                    -0.0286                    0.1300    -.0729
# 1829                    -0.0400                    0.0514    -.0571
#
#       gps_transit_stations  gps_workplaces gps_residential  \
# 200                 -0.431        -0.37300          0.1200
# 401                 -0.379        -0.41300          0.1020
# 602                 -0.336        -0.35600          0.0843
# 803                 -0.503        -0.46900          0.1360
# 1004                -0.350        -0.34600          0.0614
# ...                    ...             ...             ...
# 1025                -0.343        -0.22900          0.1110
# 1226                -0.193        -0.07860          0.0386
# 1427                -0.160        -0.02290          0.0243
# 1628                -0.123        -0.00571          0.0214
# 1829                -0.103        -0.01290          0.0157
#
#       gps_away_from_home  concat  New Cases Per Million People  \
# 200              -0.1420     911                         104.0
# 401              -0.1110     911                          30.0
# 602              -0.0959     911                         130.0
# 803              -0.1490     911                          59.0
# 1004             -0.0638     911                         149.0
# ...                  ...     ...                           ...
# 1025             -0.1410     315                           7.0
# 1226             -0.0517     315                           5.0
# 1427             -0.0365     315                           7.0
# 1628             -0.0334     315                           2.0
# 1829             -0.0224     315                           2.0
#
#       Total Cases Per Million People
# 200                          25108.0
# 401                          29020.0
# 602                          29706.0
# 803                           9197.0
# 1004                         18943.0
# ...                              ...
# 1025                            42.0
# 1226                            39.0
# 1427                            39.0
# 1628                             5.0
# 1829                             4.0
#
# [1810 rows x 23 columns]

# %%
la_df = completed_city_data.loc[(completed_city_data['cityname'] =='Los Angeles')]
nyc_df=completed_city_data.loc[(completed_city_data['cityname'] =='New York City')]
dallas_df=completed_city_data.loc[(completed_city_data['cityname'] =='Dallas')]
seattle_df=completed_city_data.loc[(completed_city_data['cityname'] =='Seattle')]
detroit_df=completed_city_data.loc[(completed_city_data['cityname'] =='Detroit')]
sf_df=completed_city_data.loc[(completed_city_data['cityname'] =='San Francisco')]
boston_df=completed_city_data.loc[(completed_city_data['cityname'] =='Boston')]
denver_df=completed_city_data.loc[(completed_city_data['cityname'] =='Denver')]
miami_df=completed_city_data.loc[(completed_city_data['cityname'] =='Miami')]
honolulu_df=completed_city_data.loc[(completed_city_data['cityname'] =='Honolulu')]
march_df=completed_city_data.loc[(completed_city_data['month'] =='3')]
april_df=completed_city_data.loc[(completed_city_data['month'] =='4')]
may_df=completed_city_data.loc[(completed_city_data['month'] =='5')]
june_df=completed_city_data.loc[(completed_city_data['month'] =='6')]
july_df=completed_city_data.loc[(completed_city_data['month'] =='7')]
august_df=completed_city_data.loc[(completed_city_data['month'] =='8')]
september_df=completed_city_data.loc[(completed_city_data['month'] =='9')]







completed_city_data.dtypes
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/ops/array_ops.py:253: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   res_values = method(rvalues)
# cityid                              int64
# cityname                           object
# stateabbrev                        object
# statename                          object
# statefips                           int64
# city_pop2019                        int64
# year                                int64
# month                               int64
# day                                 int64
# case_count                          int64
# new_case_count                      int64
# case_rate                         float64
# new_case_rate                      object
# gps_retail_and_recreation         float64
# gps_grocery_and_pharmacy          float64
# gps_parks                          object
# gps_transit_stations              float64
# gps_workplaces                    float64
# gps_residential                   float64
# gps_away_from_home                float64
# concat                              int64
# New Cases Per Million People      float64
# Total Cases Per Million People    float64
# dtype: object

# %%
weather_averages=pd.read_csv("Resources/CSVFiles/marchseptember.csv")
city_average=completed_city_data.groupby(["cityname","month"]).agg({'gps_away_from_home':'mean'})
city_average=city_average.reset_index()

# %%
city_average=city_average.rename(columns={"cityname": "Name", "month": "Period"})
temp_outside_df=pd.merge(weather_averages,city_average, on=["Name","Period"])
temp_outside_df.rename(columns={"gps_parks": "Time Spend not at home vs Baseline"})
# Out:
#       Name  Period  Maximum Temperature  Minimum Temperature  Temperature  \
# 0   Dallas       3                 88.1                 42.2         64.4
# 1   Dallas       4                 96.2                 41.0         65.9
# 2   Dallas       5                 95.0                 55.1         75.2
# 3   Dallas       6                 99.0                 65.0         83.7
# 4   Dallas       7                101.9                 74.0         86.4
# ..     ...     ...                  ...                  ...          ...
# 65   Miami       5                 87.7                 66.5         78.9
# 66   Miami       6                 90.2                 74.7         83.4
# 67   Miami       7                 96.2                 74.9         84.6
# 68   Miami       8                 92.0                 75.2         85.2
# 69   Miami       9                 91.1                 75.1         83.6
#
#     Wind Chill  Heat Index  Precipitation  Snow Depth  Wind Speed  Wind Gust  \
# 0         37.2        88.1           8.97         NaN        23.0       40.3
# 1         33.1        93.7           1.27         NaN        27.7       40.3
# 2          NaN       101.1           4.77         NaN        25.3       43.0
# 3          NaN       101.4           5.97         NaN        31.1       49.2
# 4          NaN       110.3           1.46         NaN        23.0       55.3
# ..         ...         ...            ...         ...         ...        ...
# 65         NaN        93.6          14.60         NaN        23.7       33.8
# 66         NaN       100.3           5.63         NaN        15.7       24.2
# 67         NaN       105.5          10.16         NaN        21.8       33.3
# 68         NaN       104.9           7.38         NaN        24.9       35.8
# 69         NaN       104.9           5.59         NaN        25.3       39.1
#
#     Visibility  Cloud Cover  Relative Humidity  gps_away_from_home
# 0          8.8         66.9              69.38           -0.161682
# 1          9.5         58.8              60.76           -0.236500
# 2          9.7         52.1              61.31           -0.167161
# 3          9.7         41.9              54.04           -0.123500
# 4          9.8         44.9              59.85           -0.130387
# ..         ...          ...                ...                 ...
# 65         9.4         13.9              72.73           -0.229871
# 66         9.8         12.7              75.05           -0.164167
# 67         9.7         16.9              72.30           -0.174065
# 68         9.7         15.9              73.98           -0.161613
# 69         9.6         21.2              75.81           -0.138091
#
# [70 rows x 15 columns]

# %% [markdown]
# # Temperature Data

# %% [markdown]
# The following data was pulled from Visualcrossing.com and created/cleaned by Jess.

# %%
#Clean Dataframes
del city_df["Wind Chill"]
del city_df["Heat Index"]
del city_df["Snow Depth"]
del city_df["Visibility"]

#Rename Headers
city_df=city_df.rename(columns={"Period":"month"})

# %%
city_df
# Out:
#       Name  month  Maximum Temperature  Minimum Temperature  Temperature  \
# 0   Dallas      3                 88.1                 42.2         64.4
# 1   Dallas      4                 96.2                 41.0         65.9
# 2   Dallas      5                 95.0                 55.1         75.2
# 3   Dallas      6                 99.0                 65.0         83.7
# 4   Dallas      7                101.9                 74.0         86.4
# ..     ...    ...                  ...                  ...          ...
# 65   Miami      5                 87.7                 66.5         78.9
# 66   Miami      6                 90.2                 74.7         83.4
# 67   Miami      7                 96.2                 74.9         84.6
# 68   Miami      8                 92.0                 75.2         85.2
# 69   Miami      9                 91.1                 75.1         83.6
#
#     Precipitation  Wind Speed  Wind Gust  Cloud Cover  Relative Humidity
# 0            8.97        23.0       40.3         66.9              69.38
# 1            1.27        27.7       40.3         58.8              60.76
# 2            4.77        25.3       43.0         52.1              61.31
# 3            5.97        31.1       49.2         41.9              54.04
# 4            1.46        23.0       55.3         44.9              59.85
# ..            ...         ...        ...          ...                ...
# 65          14.60        23.7       33.8         13.9              72.73
# 66           5.63        15.7       24.2         12.7              75.05
# 67          10.16        21.8       33.3         16.9              72.30
# 68           7.38        24.9       35.8         15.9              73.98
# 69           5.59        25.3       39.1         21.2              75.81
#
# [70 rows x 10 columns]

# %%
#create dataframe grouped by City and Month
month_temp=city_df.groupby(["Name", "month"])
month_temp.head()
# Out:
#       Name  month  Maximum Temperature  Minimum Temperature  Temperature  \
# 0   Dallas      3                 88.1                 42.2         64.4
# 1   Dallas      4                 96.2                 41.0         65.9
# 2   Dallas      5                 95.0                 55.1         75.2
# 3   Dallas      6                 99.0                 65.0         83.7
# 4   Dallas      7                101.9                 74.0         86.4
# ..     ...    ...                  ...                  ...          ...
# 65   Miami      5                 87.7                 66.5         78.9
# 66   Miami      6                 90.2                 74.7         83.4
# 67   Miami      7                 96.2                 74.9         84.6
# 68   Miami      8                 92.0                 75.2         85.2
# 69   Miami      9                 91.1                 75.1         83.6
#
#     Precipitation  Wind Speed  Wind Gust  Cloud Cover  Relative Humidity
# 0            8.97        23.0       40.3         66.9              69.38
# 1            1.27        27.7       40.3         58.8              60.76
# 2            4.77        25.3       43.0         52.1              61.31
# 3            5.97        31.1       49.2         41.9              54.04
# 4            1.46        23.0       55.3         44.9              59.85
# ..            ...         ...        ...          ...                ...
# 65          14.60        23.7       33.8         13.9              72.73
# 66           5.63        15.7       24.2         12.7              75.05
# 67          10.16        21.8       33.3         16.9              72.30
# 68           7.38        24.9       35.8         15.9              73.98
# 69           5.59        25.3       39.1         21.2              75.81
#
# [70 rows x 10 columns]

# %%
#find just detroit information and create dataframe
det_df=city_df.loc[city_df["Name"] == "Detroit", :]
det_df
# Out:
#        Name  month  Maximum Temperature  Minimum Temperature  Temperature  \
# 49  Detroit      3                 63.6                 20.6         40.5
# 50  Detroit      4                 70.0                 25.8         44.9
# 51  Detroit      5                 88.8                 30.1         57.3
# 52  Detroit      6                 91.5                 47.6         71.4
# 53  Detroit      7                 93.5                 62.8         77.4
# 54  Detroit      8                 92.3                 57.4         73.2
# 55  Detroit      9                 83.7                 39.1         63.7
#
#     Precipitation  Wind Speed  Wind Gust  Cloud Cover  Relative Humidity
# 49           2.79        31.8       52.8         34.1              72.02
# 50           1.76        29.6       49.4         31.7              64.55
# 51           3.34        23.4       43.6         27.1              65.69
# 52           3.90        28.8       47.2         13.5              60.45
# 53           4.93        16.7       37.8         14.8              67.06
# 54           6.74        19.9       34.4         16.7              68.78
# 55           2.55        23.7       40.3         19.9              71.62

# %%
#read and clean COVID data
covid_df
# Out:
#       Unnamed: 0  cityid       cityname stateabbrev      statename  statefips  \
# 0            200       1    Los Angeles          CA     California          6
# 1            401       2  New York City          NY       New York         36
# 2            602       7         Dallas          TX          Texas         48
# 3            803       9        Seattle          WA     Washington         53
# 4           1004      13        Detroit          MI       Michigan         26
# ...          ...     ...            ...         ...            ...        ...
# 1805        1025      21  San Francisco          CA     California          6
# 1806        1226      25         Boston          MA  Massachusetts         25
# 1807        1427      28         Denver          CO       Colorado          8
# 1808        1628      38          Miami          FL        Florida         12
# 1809        1829      48       Honolulu          HI         Hawaii         15
#
#       city_pop2019  year  month  day  case_count  new_case_count  case_rate  \
# 0         10039107  2020      9   11      252066            1042   2511.000
# 1          8336817  2020      9   11      241936             250   2902.000
# 2          2635516  2020      9   11       78291             343   2971.000
# 3          2252782  2020      9   11       20718             133    920.000
# 4          1749343  2020      9   11       33138             261   1894.000
# ...            ...   ...    ...  ...         ...             ...        ...
# 1805        881549  2020      3   15          37               6      4.200
# 1806        803907  2020      3   15          31               4      3.860
# 1807        727211  2020      3   15          28               5      3.850
# 1808       2716940  2020      3   15          13               5      0.478
# 1809        974563  2020      3   15           4               2      0.410
#
#       new_case_rate  gps_away_from_home  New Cases Per Million People  \
# 0            8.0500             -0.1420                         104.0
# 1            3.0800             -0.1110                          30.0
# 2           12.0000             -0.0959                         130.0
# 3            3.9700             -0.1490                          59.0
# 4           10.5000             -0.0638                         149.0
# ...             ...                 ...                           ...
# 1805         0.4210             -0.1410                           7.0
# 1806         0.3910             -0.0517                           5.0
# 1807         0.5110             -0.0365                           7.0
# 1808         0.0684             -0.0334                           2.0
# 1809         0.0293             -0.0224                           2.0
#
#       Total Cases Per Million People
# 0                            25108.0
# 1                            29020.0
# 2                            29706.0
# 3                             9197.0
# 4                            18943.0
# ...                              ...
# 1805                            42.0
# 1806                            39.0
# 1807                            39.0
# 1808                             5.0
# 1809                             4.0
#
# [1810 rows x 17 columns]

# %%
#Clean and Rename Headers
covid_data=covid_df.rename(columns={"cityid":"City ID", "cityname":"Name",
                                    "stateabbrev":"Abbreviation","statename":"State Name",
                                   "city_pop2019": "City Population", "year": "Year",
                                   "new_case_count": "New Case Count", "case_rate": "Case Rate",
                                   "new_case_rate": "New Case Rate", "case_count": "Case Count"})


del covid_data["gps_away_from_home"]







covid_data
# Out:
#       Unnamed: 0  City ID           Name Abbreviation     State Name  \
# 0            200        1    Los Angeles           CA     California
# 1            401        2  New York City           NY       New York
# 2            602        7         Dallas           TX          Texas
# 3            803        9        Seattle           WA     Washington
# 4           1004       13        Detroit           MI       Michigan
# ...          ...      ...            ...          ...            ...
# 1805        1025       21  San Francisco           CA     California
# 1806        1226       25         Boston           MA  Massachusetts
# 1807        1427       28         Denver           CO       Colorado
# 1808        1628       38          Miami           FL        Florida
# 1809        1829       48       Honolulu           HI         Hawaii
#
#       statefips  City Population  Year  month  day  Case Count  \
# 0             6         10039107  2020      9   11      252066
# 1            36          8336817  2020      9   11      241936
# 2            48          2635516  2020      9   11       78291
# 3            53          2252782  2020      9   11       20718
# 4            26          1749343  2020      9   11       33138
# ...         ...              ...   ...    ...  ...         ...
# 1805          6           881549  2020      3   15          37
# 1806         25           803907  2020      3   15          31
# 1807          8           727211  2020      3   15          28
# 1808         12          2716940  2020      3   15          13
# 1809         15           974563  2020      3   15           4
#
#       New Case Count  Case Rate  New Case Rate  New Cases Per Million People  \
# 0               1042   2511.000         8.0500                         104.0
# 1                250   2902.000         3.0800                          30.0
# 2                343   2971.000        12.0000                         130.0
# 3                133    920.000         3.9700                          59.0
# 4                261   1894.000        10.5000                         149.0
# ...              ...        ...            ...                           ...
# 1805               6      4.200         0.4210                           7.0
# 1806               4      3.860         0.3910                           5.0
# 1807               5      3.850         0.5110                           7.0
# 1808               5      0.478         0.0684                           2.0
# 1809               2      0.410         0.0293                           2.0
#
#       Total Cases Per Million People
# 0                            25108.0
# 1                            29020.0
# 2                            29706.0
# 3                             9197.0
# 4                            18943.0
# ...                              ...
# 1805                            42.0
# 1806                            39.0
# 1807                            39.0
# 1808                             5.0
# 1809                             4.0
#
# [1810 rows x 16 columns]

# %%
#Create Grouped dataframe by Month and Sums
month_covid=covid_data.groupby(["Name", "month"])
month_covid.sum()
# Out:
#                Unnamed: 0  City ID  statefips  City Population   Year  day  \
# Name    month
# Boston  3           20978      425        425         13666419  34340  391
#         4           37725      750        750         24117210  60600  465
#         5           39928      775        775         24921117  62620  496
#         6           39555      750        750         24117210  60600  465
#         7           41819      775        775         24921117  62620  496
# ...                   ...      ...        ...              ...    ...  ...
# Seattle 5           21235      279       1643         69836242  62620  496
#         6           21465      270       1590         67583460  60600  465
#         7           23126      279       1643         69836242  62620  496
#         8           24087      279       1643         69836242  62620  496
#         9            8778       99        583         24780602  22220   66
#
#                Case Count  New Case Count  Case Rate  New Case Rate  \
# Name    month
# Boston  3            6639            1346      826.5         98.821
#         4          205735           11517    25591.0       1372.600
#         5          497778            5046    61920.0        727.920
#         6          579350            1883    72065.0        253.500
#         7          634468            1403    78923.0        156.210
# ...                   ...             ...        ...            ...
# Seattle 5          228112            1851    10126.0         88.560
#         6          269119            2037    11950.0         81.680
#         7          393928            5018    17487.0        218.600
#         8          546508            4468    24259.0        203.010
#         9          222507            1034     9878.0         48.300
#
#                New Cases Per Million People  Total Cases Per Million People
# Name    month
# Boston  3                            1676.0                          8258.0
#         4                           14326.0                        255919.0
#         5                            6276.0                        619200.0
#         6                            2344.0                        720666.0
#         7                            1746.0                        789232.0
# ...                                     ...                             ...
# Seattle 5                             825.0                        101258.0
#         6                             906.0                        119459.0
#         7                            2228.0                        174861.0
#         8                            1982.0                        242593.0
#         9                             460.0                         98772.0
#
# [70 rows x 12 columns]

# %%
# Converting a GroupBy object into a DataFrame
month_new_case = pd.DataFrame(month_covid["New Cases Per Million People"].sum())

month_new_case.reset_index()
# Out:
#        Name  month  New Cases Per Million People
# 0    Boston      3                        1676.0
# 1    Boston      4                       14326.0
# 2    Boston      5                        6276.0
# 3    Boston      6                        2344.0
# 4    Boston      7                        1746.0
# ..      ...    ...                           ...
# 65  Seattle      5                         825.0
# 66  Seattle      6                         906.0
# 67  Seattle      7                        2228.0
# 68  Seattle      8                        1982.0
# 69  Seattle      9                         460.0
#
# [70 rows x 3 columns]

# %%
#converting temperature data in to a dataframe
city_month_temp = pd.DataFrame(month_temp["Temperature"].sum())
city_month_temp.reset_index()
# Out:
#        Name  month  Temperature
# 0    Boston      3         42.8
# 1    Boston      4         45.9
# 2    Boston      5         58.0
# 3    Boston      6         69.5
# 4    Boston      7         75.5
# ..      ...    ...          ...
# 65  Seattle      5         59.0
# 66  Seattle      6         61.7
# 67  Seattle      7         66.8
# 68  Seattle      8         67.8
# 69  Seattle      9         66.3
#
# [70 rows x 3 columns]

# %%
casestemp_df=pd.merge(city_month_temp,month_new_case,on=["Name","month"],how="outer")
casestemp_df

casestemp=casestemp_df.reset_index()

# %%
#Create a detroit temp dataframe
detroit_temp=casestemp.loc[casestemp["Name"]=="Detroit",:]

detroit_temp
# Out:
#        Name  month  Temperature  New Cases Per Million People
# 21  Detroit      3         40.5                        2130.0
# 22  Detroit      4         44.9                        7440.0
# 23  Detroit      5         57.3                        2112.0
# 24  Detroit      6         71.4                        1345.0
# 25  Detroit      7         77.4                        2461.0
# 26  Detroit      8         73.2                        2383.0
# 27  Detroit      9         63.7                        1076.0

# %%
#Create a Miami temp dataframe
miami_temp=casestemp.loc[casestemp["Name"]=="Miami",:]

miami_temp
# Out:
#      Name  month  Temperature  New Cases Per Million People
# 42  Miami      3         75.7                         779.0
# 43  Miami      4         80.1                        3657.0
# 44  Miami      5         78.9                        2187.0
# 45  Miami      6         83.4                        6925.0
# 46  Miami      7         84.6                       30046.0
# 47  Miami      8         85.2                       14150.0
# 48  Miami      9         83.6                        2381.0

# %%
miami_average=miami_temp["Temperature"].mean()
detroit_average=detroit_temp["Temperature"].mean()

# %%
round(miami_average,1)
# Out:
# 81.6

# %%
round(detroit_average,1)
# Out:
# 61.2

# %%
#Creat a dataframe for the monthly Relative Humidity
city_month_humidity = pd.DataFrame(month_temp["Relative Humidity"].sum())
city_month_humidity.reset_index()
# Out:
#        Name  month  Relative Humidity
# 0    Boston      3              57.33
# 1    Boston      4              59.53
# 2    Boston      5              57.51
# 3    Boston      6              64.90
# 4    Boston      7              70.02
# ..      ...    ...                ...
# 65  Seattle      5              63.60
# 66  Seattle      6              66.02
# 67  Seattle      7              60.34
# 68  Seattle      8              59.93
# 69  Seattle      9              66.05
#
# [70 rows x 3 columns]

# %%
caseshumidity_df=pd.merge(city_month_humidity,month_new_case,on=["Name","month"],how="outer")



caseshumidity_df["Relative Humidity"].dropna()
caseshumidity=caseshumidity_df.reset_index()

caseshumidity
# Out:
#              Name  month  Relative Humidity  New Cases Per Million People
# 0          Boston      3              57.33                        1676.0
# 1          Boston      4              59.53                       14326.0
# 2          Boston      5              57.51                        6276.0
# 3          Boston      6              64.90                        2344.0
# 4          Boston      7              70.02                        1746.0
# ..            ...    ...                ...                           ...
# 86  San Francisco      5                NaN                        1199.0
# 87  San Francisco      6                NaN                        1185.0
# 88  San Francisco      7                NaN                        3373.0
# 89  San Francisco      8                NaN                        3313.0
# 90  San Francisco      9                NaN                         788.0
#
# [91 rows x 4 columns]

# %%
#drop NAN
caseshumidity=caseshumidity.dropna(how='any')
caseshumidity
# Out:
#         Name  month  Relative Humidity  New Cases Per Million People
# 0     Boston      3              57.33                        1676.0
# 1     Boston      4              59.53                       14326.0
# 2     Boston      5              57.51                        6276.0
# 3     Boston      6              64.90                        2344.0
# 4     Boston      7              70.02                        1746.0
# 5     Boston      8              64.02                        2800.0
# 6     Boston      9              62.62                        -548.0
# 7     Dallas      3              69.38                         234.0
# 8     Dallas      4              60.76                        1099.0
# 9     Dallas      5              61.31                        2544.0
# 10    Dallas      6              54.04                        4214.0
# 11    Dallas      7              59.85                       11370.0
# 12    Dallas      8              51.04                        8832.0
# 13    Dallas      9              71.59                        1410.0
# 14    Denver      3              57.16                         711.0
# 15    Denver      4              49.88                        3386.0
# 16    Denver      5              52.94                        3816.0
# 17    Denver      6              37.36                        1812.0
# 18    Denver      7              44.23                        3484.0
# 19    Denver      8              35.74                        2258.0
# 20    Denver      9              40.65                         577.0
# 21   Detroit      3              72.02                        2130.0
# 22   Detroit      4              64.55                        7440.0
# 23   Detroit      5              65.69                        2112.0
# 24   Detroit      6              60.45                        1345.0
# 25   Detroit      7              67.06                        2461.0
# 26   Detroit      8              68.78                        2383.0
# 27   Detroit      9              71.62                        1076.0
# 28  Honolulu      3              70.93                         157.0
# 29  Honolulu      4              67.73                         247.0
# 30  Honolulu      5              63.37                          22.0
# 31  Honolulu      6              63.39                         233.0
# 32  Honolulu      7              64.76                        1131.0
# 33  Honolulu      8              61.92                        6092.0
# 34  Honolulu      9              60.96                        1859.0
# 42     Miami      3              64.85                         779.0
# 43     Miami      4              69.86                        3657.0
# 44     Miami      5              72.73                        2187.0
# 45     Miami      6              75.05                        6925.0
# 46     Miami      7              72.30                       30046.0
# 47     Miami      8              73.98                       14150.0
# 48     Miami      9              75.81                        2381.0
# 63   Seattle      3              71.32                         863.0
# 64   Seattle      4              62.93                        1766.0
# 65   Seattle      5              63.60                         825.0
# 66   Seattle      6              66.02                         906.0
# 67   Seattle      7              60.34                        2228.0
# 68   Seattle      8              59.93                        1982.0
# 69   Seattle      9              66.05                         460.0

# %%
#Create a detroit humidity dataframe
detroit_humidity=caseshumidity.loc[caseshumidity["Name"]=="Detroit",:]

detroit_humidity
# Out:
#        Name  month  Relative Humidity  New Cases Per Million People
# 21  Detroit      3              72.02                        2130.0
# 22  Detroit      4              64.55                        7440.0
# 23  Detroit      5              65.69                        2112.0
# 24  Detroit      6              60.45                        1345.0
# 25  Detroit      7              67.06                        2461.0
# 26  Detroit      8              68.78                        2383.0
# 27  Detroit      9              71.62                        1076.0

# %%
detroitcases=detroit_humidity

# %% [markdown]
# # T-TEST

# %% [markdown]
# Independent t-tests will compare the means of 2 independent populations.
# <br />
# <br />
# <b>Assumptions</b> <br />
# -Data is normally distributed<br />
# -Data is independent<br />
# -Data is homogenous (The standard deviations are roughly equal)<br />

# %% [markdown]
# <b>Null Hypothesis</b> Cities with an average temperature greater than 70 are not less likely to have a higher amount of new COVID cases, compared to cities with average temperatures less than 70.<br />
# <br />
# <br />
# <b>Alternative Hypothese</b> Cities with an average temperature greater than 70 are likely to have higher new COVID cases, compared to cities with average temperatures less than 70..<br />
# <br />
#
# We picked two cities that we noted have varying differences in temperatures, with Detroit's average at 61.2 and Miami's average at 81.6, in order to test if the warmer temperature increased COVID cases over this time study.
#
# <b>Significance Level</b> The significance level is 0.05<br />
# <br />
# <br />
# <b>P-Value</b> The P-Value is calculated to be 0.19<br />
# <br />
# <br />
# <b>Conclusion</b> After conducting a statistical test comparing the new COVID cases in both Detroit and Miami over the 6 month span, we determined the p-value to be 0.19.  This is above the desired significance level of 0.05 and thus fails to reject the null hypothesis. Based on the test, there is no support that the (altherntive) hypothesis stating that temperatures above 70 causes there to be more new COVID cases.

# %% [markdown]
# Population1 below is Detroit's new cases per million people and Population2 below is Miamia's new cases per million people.

# %%
#set populations
population1=detroit_temp["New Cases Per Million People"]
population2=miami_temp["New Cases Per Million People"]

# %%
population1.describe()
# Out:
# count       7.000000
# mean     2706.714286
# std      2151.315080
# min      1076.000000
# 25%      1728.500000
# 50%      2130.000000
# 75%      2422.000000
# max      7440.000000
# Name: New Cases Per Million People, dtype: float64

# %%
population2.describe()
# Out:
# count        7.000000
# mean      8589.285714
# std      10479.679205
# min        779.000000
# 25%       2284.000000
# 50%       3657.000000
# 75%      10537.500000
# max      30046.000000
# Name: New Cases Per Million People, dtype: float64

# %%
    # Scatter Plot of Data
    plt.subplot(2, 1, 1)
    plt.scatter(range(len(population1)), population1, label="population1")
    plt.scatter(range(len(population2)), population2, label="population2")
    plt.legend()

# %%
# Note: Setting equal_var=False performs Welch's t-test which does 
# not assume equal population variance
stats.ttest_ind(population1, population2, equal_var=False)
# Out:
# Ttest_indResult(statistic=-1.4548052290399018, pvalue=0.19221846028439218)

# %% [markdown]
# # Cities API Pull - Latitudes

# %% [markdown]
# The data below is pulled from a Google API to find the Latitude of the respective 10 cities.

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
api_key="e9f34fe30c3508b1804ca865ed96b3b4"

# Build partial query URL
query_url = f"{url}appid={api_key}&q="

# %%
cities = ["Boston", "Dallas", "Denver", "Detroit", "Honolulu", "Los Angeles", "Miami", "New York City", "San Francisco", "Seattle"]

# set up lists to hold reponse info
lat = []
lng = []


# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
    lat.append(response['coord']['lat'])
    lng.append(response['coord']['lon'])


print(f"The latitude information received is: {lat}")
print(f"The longitude information received is: {lng}")
# Out:
# The latitude information received is: [42.36, 32.77, 39.74, 42.33, 21.31, 34.05, 25.77, 40.71, 37.77, 47.61]
# The longitude information received is: [-71.06, -96.78, -104.98, -83.05, -157.86, -118.24, -80.19, -74.01, -122.42, -122.33]

# %%
# create a data frame from cities and lat
lat_dict = {
    "city": cities,
    "lat": lat,
    'lng': lng,
}
lat_data = pd.DataFrame(lat_dict)

lat_data=lat_data.rename(columns={"city":"Name"})

lat_data
# Out:
#             Name    lat     lng
# 0         Boston  42.36  -71.06
# 1         Dallas  32.77  -96.78
# 2         Denver  39.74 -104.98
# 3        Detroit  42.33  -83.05
# 4       Honolulu  21.31 -157.86
# 5    Los Angeles  34.05 -118.24
# 6          Miami  25.77  -80.19
# 7  New York City  40.71  -74.01
# 8  San Francisco  37.77 -122.42
# 9        Seattle  47.61 -122.33

# %%
month_sums=month_new_case.groupby("Name").sum()
month_sums.reset_index()
# Out:
#             Name  New Cases Per Million People
# 0         Boston                       28620.0
# 1         Dallas                       29703.0
# 2         Denver                       16044.0
# 3        Detroit                       18947.0
# 4       Honolulu                        9741.0
# 5    Los Angeles                       25106.0
# 6          Miami                       60125.0
# 7  New York City                       28990.0
# 8  San Francisco                       11528.0
# 9        Seattle                        9030.0

# %%
# Merge two dataframes using an outer join
lat_merge_df = pd.merge(lat_data, month_sums, on="Name", how="outer")
lat_merge_df

latlng_merge_df=pd.merge(lat_merge_df, lat_data, on="Name", how="inner")
del latlng_merge_df["lat_y"]
del latlng_merge_df["lng_y"]

latlng_merge_df=latlng_merge_df.rename(columns={"lat_x": "Latitude", "lng_x": "Longitude"})



latlng_merge_df
# Out:
#             Name  Latitude  Longitude  New Cases Per Million People
# 0         Boston     42.36     -71.06                       28620.0
# 1         Dallas     32.77     -96.78                       29703.0
# 2         Denver     39.74    -104.98                       16044.0
# 3        Detroit     42.33     -83.05                       18947.0
# 4       Honolulu     21.31    -157.86                        9741.0
# 5    Los Angeles     34.05    -118.24                       25106.0
# 6          Miami     25.77     -80.19                       60125.0
# 7  New York City     40.71     -74.01                       28990.0
# 8  San Francisco     37.77    -122.42                       11528.0
# 9        Seattle     47.61    -122.33                        9030.0

# %% [markdown]
# # Create a Heat Map of Cases and Location

# %%
# Store latitude and longitude in locations
locations = latlng_merge_df[["Latitude", "Longitude"]]

# Fill NaN values and convert to float
millioncases = latlng_merge_df["New Cases Per Million People"].astype(float)

# %%
# Plot Heatmap
fig = gmaps.figure()

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=millioncases, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=1)


# Add layer
fig.add_layer(heat_layer)

# Display figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# # Visualizing the Data

# %% [markdown]
# Below you will find a series of 9 scatterplots that find any potential correlation between the following:
#
# 1. Average Temperature (F) vs. New Case Count (Monthly) - All Cities
# 2. Average Temperature (F) vs. New Case Count (Monthly) - Detroit
# 3. Relative Humidity (%) vs. New Case Count (Monthly) - All Cities
# 4. Relative Humidity (%) vs. New Case Count (Monthly) - Detroit
# 5. Avg Time spent away from Home(vs the baseline) vs New Covid Case Count
# 6. Detroit Time spent away from home(vs the baseline) vs New Covid Cases
# 7. Avg Time spent away from Home(vs the baseline) vs Average Monthly Temperature
# 8. Detroit Avg Time spent away from Home(vs the baseline) vs Average Monthly Temperature
# 9. Latitude vs. Total New Cases (March - September)

# %%
# Add the linear regression equation and line to plot
x_values = casestemp_df['Temperature']
y_values = casestemp_df['New Cases Per Million People']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Avg. Monthly Temperature vs. Monthly New Cases (Per Million People)")
plt.xlabel('Temperature')
plt.ylabel('Monthly New Cases (Per Million People)')
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.savefig('OutputImages/tempcasesall.png', dpi=300)


plt.show()
# Out:
# The r-value is: nan
# y = nanx + nan

# %%
# Add the linear regression equation and line to plot
x_values = detroit_temp['Temperature']
y_values = detroit_temp['New Cases Per Million People']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Avg. Monthly Temperature vs. Monthly New Cases (Per Million People) in Detroit")
plt.xlabel('Temperature')
plt.ylabel('Monthly New Cases (Per Million People)')
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.savefig('OutputImages/tempcasesdetroit.png', dpi=300)


plt.show()
# Out:
# The r-value is: 0.23121468284730143
# y = -72.36x + 7135.37

# %%
#The below scatterplot is showing the line chart of temperature in Detroit from March - September
time=[3,4,5,6,7,8,9]
temperature_line_data=detroit_temp['Temperature']
temperature_line = plt.plot(time, temperature_line_data, color="red")
plt.title("Avg. Temperature in Detroit from March to September 2020")
plt.xlabel("Months March to September")
plt.ylabel("Temperature in Farenheit")
plt.savefig('OutputImages/tempdetroit.png', dpi=300)


plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
#The below scatterplot is showing the line chart of new cases (per million people) in Detroit from March - September


time=[3,4,5,6,7,8,9]
temperature_line_data=detroit_temp['Temperature']
covid_line_data=detroit_temp["New Cases Per Million People"]
covid_line = plt.plot(time, covid_line_data, color="blue")
plt.title("New Cases of COVID (Per Million People) in Detroit from March to September 2020")
plt.xlabel("Months March to September")
plt.ylabel("Number of New Cases (Per Million People")
plt.savefig('OutputImages/tempcaseslinedetroit.png', dpi=300)


plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Add the linear regression equation and line to plot
x_values = caseshumidity['Relative Humidity']
y_values = caseshumidity['New Cases Per Million People']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Avg. Monthly Relative Humidity Percentage vs. Monthly New Cases (Per Million People)")
plt.xlabel('Relative Humidity')
plt.ylabel('Monthly New Cases (Per Million People)')
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.savefig('OutputImages/newcaseshumidityall.png', dpi=300)


plt.show()
# Out:
# The r-value is: 0.010482616119399853
# y = 56.5x + -13.94

# %%
# Add the linear regression equation and line to plot
x_values = detroit_humidity['Relative Humidity']
y_values = detroit_humidity['New Cases Per Million People']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("Relative Humidity of Detroit vs. Monthly New Cases (Per Million People) for Detroit")
plt.xlabel('Relative Humidity')
plt.ylabel('Monthly New Cases(Per Million People)')
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.savefig('OutputImages/humiditynewcasesdetroit.png', dpi=300)


plt.show()
# Out:
# The r-value is: 0.06001051467345702
# y = -129.0x + 11371.17

# %%
plt.scatter(completed_city_data['gps_away_from_home'],completed_city_data['New Cases Per Million People'])
plt.title("Avg Time Spent Away from Home(vs the Baseline) vs New Cases Per Million People")
plt.ylabel("New Cases Per Million People")
plt.xlabel("Avg Time Spent Away from Home(vs the Baseline)")
plt.grid(True)
plt.savefig('OutputImages/newcasestimeawayall.png', dpi=300)

# %%
(slope,intercept,rvalue,pvalue,stderr)=st.linregress(detroit_df['gps_away_from_home'],detroit_df['New Cases Per Million People'])

regress_values = slope*detroit_df['gps_away_from_home']+intercept

line_eq = "y=" + str(round(slope,2)) + "x + " + str(round(intercept,2))



plt.scatter(detroit_df['gps_away_from_home'],detroit_df['New Cases Per Million People'])
plt.title("Detroit Time Spent Away from Home(vs the Baseline) vs New Cases Per Million People")
plt.ylabel("New Cases Per Million People")
plt.grid(True)
plt.xlabel("Avg Time Spent Away from Home(vs the Baseline)")
plt.annotate(line_eq,(-.5,25),fontsize=15,color="r")
plt.plot(detroit_df['gps_away_from_home'],regress_values,"r",)



print(f'The corrleation coefficient is {round(rvalue,2)} meaning there is a moderate negative correlation.')
print(f'The Linear Regress model for this is {line_eq}')

plt.savefig('OutputImages/awaynewcasesscatter.png', dpi=300)
# Out:
# The corrleation coefficient is -0.61 meaning there is a moderate negative correlation.
# The Linear Regress model for this is y=-749.93x + 3.74

# %%
plt.scatter(temp_outside_df['gps_away_from_home'],temp_outside_df['Temperature'])
plt.title("Avg Time Spent Away from Home (vs the Baseline) vs Average Monthly Temperature")
plt.ylabel("Average Monthly Temperature")
plt.xlabel("Avg Time Spent Away from Home (vs the Baseline)")
plt.grid(True)
plt.savefig('OutputImages/timeawaytempscatter.png', dpi=300)

# %%
detroit=temp_outside_df.loc[(temp_outside_df['Name'] =='Detroit')]


(slope,intercept,rvalue,pvalue,stderr)=st.linregress(detroit['gps_away_from_home'],detroit['Temperature'])

regress_values = slope*detroit['gps_away_from_home']+intercept

line_eq = "y=" + str(round(slope,2)) + "x + " + str(round(intercept,2))



plt.scatter(detroit['gps_away_from_home'],detroit['Temperature'])
plt.title("Detroit Avg Time spent away from Home(vs the baseline) vs Average Monthly Temperature")
plt.ylabel("Avg Monthly Temp")
plt.grid(True)
plt.xlabel("Avg Time spent away from Home(vs the baseline)")
plt.annotate(line_eq,(-.5,25),fontsize=15,color="r")
plt.plot(detroit['gps_away_from_home'],regress_values,"r",)


print(f'The corrleation coefficient is {round(rvalue,2)} meaning there is a strong positive correlation.')
print(f'The Linear Regress model for this is {line_eq}')

plt.savefig('OutputImages/monthlytemptimedetroit.png', dpi=300)
# Out:
# The corrleation coefficient is 0.81 meaning there is a strong positive correlation.
# The Linear Regress model for this is y=148.02x + 80.48

# %% [markdown]
# # Looking for Outliers in Data

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
cases=month_new_case["New Cases Per Million People"]
quartiles = cases.quantile([.25,.5,.75])
lowerq = round(quartiles[0.25],2)
upperq = round(quartiles[0.75],2)
iqr = round(upperq-lowerq,2)

print(f"Find below the outlier test for monthly new cases (per million people)")



print(f"The lower quartile of New Cases is: {lowerq}")
print(f"The upper quartile of New Cases is: {upperq}")
print(f"The interquartile range of New Cases is: {iqr}")
print(f"The the median of New Cases is: {quartiles[0.5]} ")

lower_bound = round(lowerq - (1.5*iqr),2)
upper_bound = round(upperq + (1.5*iqr),2)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# Find below the outlier test for monthly new cases (per million people)
# The lower quartile of New Cases is: 1039.25
# The upper quartile of New Cases is: 3613.75
# The interquartile range of New Cases is: 2574.5
# The the median of New Cases is: 1996.0
# Values below -2822.5 could be outliers.
# Values above 7475.5 could be outliers.

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('New Cases (Per Million People) Monthly Totals')
ax1.set_ylabel('New Cases (million)')
ax1.boxplot(cases)
ax1.set_yticks(np.arange(0, 32000, 3000))
plt.savefig('OutputImages/newcasestotalboxplot.png', dpi=300)


plt.show()

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
detroitcases=detroitcases["New Cases Per Million People"]
quartiles = detroitcases.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq

print(f"Find below the outlier test for monthly new cases (per million people) for Detroit")



print(f"The lower quartile of New Cases is: {lowerq}")
print(f"The upper quartile of New Cases is: {upperq}")
print(f"The interquartile range of New Cases is: {iqr}")
print(f"The the median of New Cases is: {quartiles[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# Find below the outlier test for monthly new cases (per million people) for Detroit
# The lower quartile of New Cases is: 1728.5
# The upper quartile of New Cases is: 2422.0
# The interquartile range of New Cases is: 693.5
# The the median of New Cases is: 2130.0
# Values below 688.25 could be outliers.
# Values above 3462.25 could be outliers.

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('New Cases (Per Million People) In Detroit')
ax1.set_ylabel('New Cases (million)')
ax1.boxplot(detroitcases)
ax1.set_yticks(np.arange(0, 8000, 1000))
plt.savefig('OutputImages/newcasesedetroitboxplot.png', dpi=300)


plt.show()

# %%
# If the data is in a dataframe, we use pandas to give quartile calculations
newcases=detroit_temp["Temperature"]
quartiles = newcases.quantile([.25,.5,.75])
lowerq = round(quartiles[0.25],2)
upperq = round(quartiles[0.75],2)
iqr = round(upperq-lowerq,2)

print(f"The lower quartile of Temperature is: {lowerq}")
print(f"The upper quartile of Temperature is: {upperq}")
print(f"The interquartile range of Temperature is: {iqr}")
print(f"The the median of Temperature is: {quartiles[0.5]} ")

lower_bound = round(lowerq - (1.5*iqr),2)
upper_bound = round(upperq + (1.5*iqr),2)
print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
# Out:
# The lower quartile of Temperature is: 51.1
# The upper quartile of Temperature is: 72.3
# The interquartile range of Temperature is: 21.2
# The the median of Temperature is: 63.7
# Values below 19.3 could be outliers.
# Values above 104.1 could be outliers.

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Temperature In Detroit')
ax1.set_ylabel('Temperature (in Farenheit)')
ax1.boxplot(newcases)
ax1.set_yticks(np.arange(0, 80, 10))
plt.savefig('OutputImages/tempboxplotdetroit.png', dpi=300)


plt.show()

# %%
# Add the linear regression equation and line to plot
x_values = lat_merge_df['lat']
y_values = lat_merge_df['New Cases Per Million People']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title("City Latitude vs. Total New Cases")
plt.xlabel('Latitude')
plt.ylabel('Monthly New Cases')
print(f"The r-value is: {rvalue**2}")
print(line_eq)
plt.savefig('OutputImages/latitude.png', dpi=300)
plt.show()
# Out:
# The r-value is: 0.12237194507023588
# y = -654.55x + 47636.43

# %% [markdown]
# # Final Analysis & Limitations

# %% [markdown]
# <b>1. Individual City/State Reaction to COVID</b><br />
# A. Did the cities in our study put Stay at Home Orders in place? If so, when did the initial order start and how long did it last?<br />
# B. Outside of Stay at Home Orders, were restrictions on public places put in place? How strict were the guidelines for people being allowed to leave their homes?<br />
# <br /><br />
# <b>2. Sample Size and Profile</b><br />
# A. Did 10 cities accurately reflect the country?<br />
# B. Could we have found better data sources to pull both the historical weather, COVID tracker, and GPS data from?<br />
#   <br /><br />
# <b>3. Weather Standards</b><br />
# A. What is considered normal weather for the selected cities? Are we able to see outliers in weather patterns that may had led to an increase/decrease in cases or time spent outside the home?<br />
#     <br />
#     <br />
# <b>4. Time-Series Data</b><br />
# A.What other factors occurring during the same time could have led to our conclusions?

# %% [markdown]
# Based on our research, we can conclude that there is no strong correlation between the ten cities' weather (temperature/relative humidity) and increases with new COVID cases.  In regards to time spent outside, we did find a positive correlation between increased temperatures and time spent away from the home. However, as the populations spent more time away from home, the COVID new cases did not increase.
